# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 45 not upgraded.
# Need to get 10.3 MB of archives.
# After this operation, 34.1 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-nanum all 20200506-1 [10.3 MB]
# Fetched 10.3 MB in 2s (5,739 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-nanum.
# ...

# %% [markdown]
# # 기본설정

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 나눔고딕 폰트 경로
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'

# 폰트 프로퍼티 생성
font_prop = fm.FontProperties(fname=font_path)
plt.rc('font', family=font_prop.get_name())

# 한글 폰트가 제대로 설정되었는지 확인
print("현재 설정된 폰트:", plt.rcParams['font.family'])
# Out:
# 현재 설정된 폰트: ['NanumGothic']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
customers           = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/customers.csv')    # 고객과 관련된 정보
locations           = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/locations.csv')    # 지역과 관련된 정보
order_items         = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/order_items.csv')  # 주문 아이템과 관련된 정보
orders              = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/orders.csv')       # 주문과 관련된 정보
payments            = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/payments.csv')     # 지불과 관련된 정보
products            = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/products.csv')     # 제품과 관련된 정보
reviews             = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/reviews.csv')      # 리뷰와 관련된 정보
sellers             = pd.read_csv('/content/drive/MyDrive/데이터분석스쿨/프로젝트/데이터 톤/open/sellers.csv')      # 판매자 관련된 정보

# %% [markdown]
# ## customers

# %%
# customers 데이터 확인
customers.head()
# Out:
#       Customer_id     Customer_unique_id  Customer_zipcode_prefix  \
# 0  CUSTOMER_00000  CUSTOMER_Unique_00000                    14409
# 1  CUSTOMER_00001  CUSTOMER_Unique_00001                     9790
# 2  CUSTOMER_00002  CUSTOMER_Unique_00002                     1151
# 3  CUSTOMER_00003  CUSTOMER_Unique_00003                     8775
# 4  CUSTOMER_00004  CUSTOMER_Unique_00004                    89254
#
#            Customer_city Customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4         jaragua do sul             SC

# %%
# 컬럼명 변경
customers = customers.rename(columns={'Customer_id':'고객 ID'})
customers = customers.rename(columns={'Customer_unique_id':'고객 고유 ID'})
customers = customers.rename(columns={'Customer_zipcode_prefix':'우편번호 앞부분'})
customers = customers.rename(columns={'Customer_city':'도시'})
customers = customers.rename(columns={'Customer_state':'주'})
customers.head()
# Out:
#             고객 ID               고객 고유 ID  우편번호 앞부분                     도시   주
# 0  CUSTOMER_00000  CUSTOMER_Unique_00000     14409                 franca  SP
# 1  CUSTOMER_00001  CUSTOMER_Unique_00001      9790  sao bernardo do campo  SP
# 2  CUSTOMER_00002  CUSTOMER_Unique_00002      1151              sao paulo  SP
# 3  CUSTOMER_00003  CUSTOMER_Unique_00003      8775        mogi das cruzes  SP
# 4  CUSTOMER_00004  CUSTOMER_Unique_00004     89254         jaragua do sul  SC

# %%
# customers shape 확인
customers.shape
# Out:
# (87955, 5)

# %%
# customers 정보 확인
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87955 entries, 0 to 87954
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   고객 ID     87955 non-null  object
#  1   고객 고유 ID  87955 non-null  object
#  2   우편번호 앞부분  87955 non-null  int64
#  3   도시        87955 non-null  object
#  4   주         87955 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
# customers 결측치 확인
customers.isnull().sum()
# Out:
# 고객 ID       0
# 고객 고유 ID    0
# 우편번호 앞부분    0
# 도시          0
# 주           0
# dtype: int64

# %%
# customers 중복값 확인
print(customers.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## locations

# %%
# locations 데이터 확인
locations.head()
# Out:
#    Geolocation_zipcode_prefix  Geolocation_lat  Geolocation_lng  \
# 0                        1037       -23.545621       -46.639292
# 1                        1046       -23.546081       -46.644820
# 2                        1046       -23.546129       -46.642951
# 3                        1041       -23.544392       -46.639499
# 4                        1035       -23.541578       -46.641607
#
#   Geolocation_city Geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
# locations shape 확인
locations.shape
# Out:
# (1000163, 5)

# %%
# 컬럼명 변경
locations = locations.rename(columns={'Geolocation_zipcode_prefix':'우편번호 앞부분'})
locations = locations.rename(columns={'Geolocation_lat':'위도'})
locations = locations.rename(columns={'Geolocation_lng':'경도'})
locations = locations.rename(columns={'Geolocation_city':'도시'})
locations = locations.rename(columns={'Geolocation_state':'주'})
locations.head()
# Out:
#    우편번호 앞부분         위도         경도         도시   주
# 0      1037 -23.545621 -46.639292  sao paulo  SP
# 1      1046 -23.546081 -46.644820  sao paulo  SP
# 2      1046 -23.546129 -46.642951  sao paulo  SP
# 3      1041 -23.544392 -46.639499  sao paulo  SP
# 4      1035 -23.541578 -46.641607  sao paulo  SP

# %%
# locations 정보 확인
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column    Non-Null Count    Dtype
# ---  ------    --------------    -----
#  0   우편번호 앞부분  1000163 non-null  int64
#  1   위도        1000163 non-null  float64
#  2   경도        1000163 non-null  float64
#  3   도시        1000163 non-null  object
#  4   주         1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
# locations 결측치 확인
locations.isnull().sum()
# Out:
# 우편번호 앞부분    0
# 위도          0
# 경도          0
# 도시          0
# 주           0
# dtype: int64

# %%
# locations 중복값 확인
print(locations.duplicated(keep=False).sum())
# Out:
# 390005

# %% [markdown]
# ## order_items

# %%
# order_items 데이터 확인
order_items.head()
# Out:
#       Order_id  Order_item_id     Product_id    Seller_id  Price  \
# 0  ORDER_75477              1  PRODUCT_23128  SELLER_0452   58.9
# 1  ORDER_63604              1  PRODUCT_24351  SELLER_0414  239.9
# 2  ORDER_05566              1  PRODUCT_20226  SELLER_1637  199.0
# 3  ORDER_04632              1  PRODUCT_07878  SELLER_1445  199.9
# 4  ORDER_61452              1  PRODUCT_03505  SELLER_0581   21.9
#
#    Freight_value
# 0          13.29
# 1          19.93
# 2          17.87
# 3          18.14
# 4          12.69

# %%
# 컬럼명 변경
order_items = order_items.rename(columns={'Order_id':'주문 고유 ID'})
order_items = order_items.rename(columns={'Order_item_id':'주문 품목 수'})
order_items = order_items.rename(columns={'Product_id':'제품 고유 ID'})
order_items = order_items.rename(columns={'Seller_id':'판매자 고유 ID'})
order_items = order_items.rename(columns={'Price':'판매 가격'})
order_items = order_items.rename(columns={'Freight_value':'품목 화물 가격'})
order_items.head()
# Out:
#       주문 고유 ID  주문 품목 수       제품 고유 ID    판매자 고유 ID  판매 가격  품목 화물 가격
# 0  ORDER_75477        1  PRODUCT_23128  SELLER_0452   58.9     13.29
# 1  ORDER_63604        1  PRODUCT_24351  SELLER_0414  239.9     19.93
# 2  ORDER_05566        1  PRODUCT_20226  SELLER_1637  199.0     17.87
# 3  ORDER_04632        1  PRODUCT_07878  SELLER_1445  199.9     18.14
# 4  ORDER_61452        1  PRODUCT_03505  SELLER_0581   21.9     12.69

# %%
order_items['제품 고유 ID'].nunique()
# Out:
# 29430

# %%
# order_items shape 확인
order_items.shape
# Out:
# (100557, 6)

# %%
# order_items 정보 확인
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100557 entries, 0 to 100556
# Data columns (total 6 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   주문 고유 ID   100557 non-null  object
#  1   주문 품목 수    100557 non-null  int64
#  2   제품 고유 ID   100557 non-null  object
#  3   판매자 고유 ID  100557 non-null  object
#  4   판매 가격      100557 non-null  float64
#  5   품목 화물 가격   100557 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 4.6+ MB

# %%
# order_items 결측치 확인
order_items.isnull().sum()
# Out:
# 주문 고유 ID     0
# 주문 품목 수      0
# 제품 고유 ID     0
# 판매자 고유 ID    0
# 판매 가격        0
# 품목 화물 가격     0
# dtype: int64

# %%
# order_items 중복값 확인
print(order_items.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## orders

# %%
# orders 데이터 확인
orders.head()
# Out:
#       Order_id     Customer_id Order_status Order_purchase_timestamp  \
# 0  ORDER_00000  CUSTOMER_62232    delivered      2018-10-02 10:56:33
# 1  ORDER_00001  CUSTOMER_54059    delivered      2018-11-18 19:28:06
# 2  ORDER_00002  CUSTOMER_59535    delivered      2019-02-13 21:18:39
# 3  ORDER_00003  CUSTOMER_60516    delivered      2018-07-09 21:57:05
# 4  ORDER_00004  CUSTOMER_76957    delivered      2018-05-16 13:10:30
#
#   Order_delivered_carrier_date Order_delivered_customer_date  \
# 0          2018-10-04 19:55:00           2018-10-10 21:25:13
# 1          2018-11-22 13:39:59           2018-12-02 00:28:42
# 2          2019-02-14 19:46:34           2019-02-16 18:17:02
# 3          2018-07-11 14:58:04           2018-07-26 10:57:55
# 4          2018-05-22 10:07:46           2018-05-26 12:55:51
#
#   Order_estimated_delivery_date
# 0                    2018-10-18
# 1                    2018-12-15
# 2                    2019-02-26
# 3                    2018-08-01
# ...

# %%
# 컬럼명 변경
orders = orders.rename(columns={'Order_id':'주문 고유 ID'})
orders = orders.rename(columns={'Customer_id':'고객 ID'})
orders = orders.rename(columns={'Order_status':'주문 상태'})
orders = orders.rename(columns={'Order_purchase_timestamp':'구매 시간'})
orders = orders.rename(columns={'Order_delivered_carrier_date':'물류 처리 시간'})
orders = orders.rename(columns={'Order_delivered_customer_date':'실제 배송 날짜'})
orders = orders.rename(columns={'Order_estimated_delivery_date':'기대 배송 날짜'})
orders.head()
# Out:
#       주문 고유 ID           고객 ID      주문 상태                구매 시간  \
# 0  ORDER_00000  CUSTOMER_62232  delivered  2018-10-02 10:56:33
# 1  ORDER_00001  CUSTOMER_54059  delivered  2018-11-18 19:28:06
# 2  ORDER_00002  CUSTOMER_59535  delivered  2019-02-13 21:18:39
# 3  ORDER_00003  CUSTOMER_60516  delivered  2018-07-09 21:57:05
# 4  ORDER_00004  CUSTOMER_76957  delivered  2018-05-16 13:10:30
#
#               물류 처리 시간             실제 배송 날짜    기대 배송 날짜
# 0  2018-10-04 19:55:00  2018-10-10 21:25:13  2018-10-18
# 1  2018-11-22 13:39:59  2018-12-02 00:28:42  2018-12-15
# 2  2019-02-14 19:46:34  2019-02-16 18:17:02  2019-02-26
# 3  2018-07-11 14:58:04  2018-07-26 10:57:55  2018-08-01
# 4  2018-05-22 10:07:46  2018-05-26 12:55:51  2018-06-07

# %%
# orders shape 확인
orders.shape
# Out:
# (87955, 7)

# %%
# orders 정보 확인
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87955 entries, 0 to 87954
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주문 고유 ID  87955 non-null  object
#  1   고객 ID     87955 non-null  object
#  2   주문 상태     87955 non-null  object
#  3   구매 시간     87955 non-null  object
#  4   물류 처리 시간  87955 non-null  object
#  5   실제 배송 날짜  87955 non-null  object
#  6   기대 배송 날짜  87955 non-null  object
# dtypes: object(7)
# memory usage: 4.7+ MB

# %%
# orders 결측치 확인
orders.isnull().sum()
# Out:
# 주문 고유 ID    0
# 고객 ID       0
# 주문 상태       0
# 구매 시간       0
# 물류 처리 시간    0
# 실제 배송 날짜    0
# 기대 배송 날짜    0
# dtype: int64

# %%
# orders 중복값 확인
print(orders.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## payments

# %%
# payments 데이터 확인
payments.head()
# Out:
#       Order_id  Payment_sequential Payment_type  Payment_installments  \
# 0  ORDER_66617                   1  credit_card                     8
# 1  ORDER_86954                   1  credit_card                     1
# 2  ORDER_38852                   1  credit_card                     1
# 3  ORDER_57443                   1  credit_card                     8
# 4  ORDER_11244                   1  credit_card                     2
#
#    Payment_value
# 0          99.33
# 1          24.39
# 2          65.71
# 3         107.78
# 4         128.45

# %%
# payments shape 확인
payments.shape
# Out:
# (91971, 5)

# %%
# 컬럼명 변경
payments = payments.rename(columns={'Order_id':'주문 고유 ID'})
payments = payments.rename(columns={'Payment_sequential':'결제 시퀀스'})
payments = payments.rename(columns={'Payment_type':'지불 방법 '})
payments = payments.rename(columns={'Payment_installments':'할부 횟수'})
payments = payments.rename(columns={'Payment_value':'거래 금액'})
payments.head()
# Out:
#       주문 고유 ID  결제 시퀀스       지불 방법   할부 횟수   거래 금액
# 0  ORDER_66617       1  credit_card      8   99.33
# 1  ORDER_86954       1  credit_card      1   24.39
# 2  ORDER_38852       1  credit_card      1   65.71
# 3  ORDER_57443       1  credit_card      8  107.78
# 4  ORDER_11244       1  credit_card      2  128.45

# %%
# payments 정보 확인
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91971 entries, 0 to 91970
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주문 고유 ID  91971 non-null  object
#  1   결제 시퀀스    91971 non-null  int64
#  2   지불 방법     91971 non-null  object
#  3   할부 횟수     91971 non-null  int64
#  4   거래 금액     91971 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.5+ MB

# %%
# payments 결측치 확인
payments.isnull().sum()
# Out:
# 주문 고유 ID    0
# 결제 시퀀스      0
# 지불 방법       0
# 할부 횟수       0
# 거래 금액       0
# dtype: int64

# %%
# payments 중복값 확인
print(payments.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## products

# %%
# products 데이터 확인
products.head()
# Out:
#       Product_id Product_category_name Product_weight_g Product_length_cm  \
# 0  PRODUCT_00000             perfumery            225.0              16.0
# 1  PRODUCT_00001                  arts           1000.0              30.0
# 2  PRODUCT_00002        sports_leisure            154.0              18.0
# 3  PRODUCT_00003        home_utilities            625.0              20.0
# 4  PRODUCT_00004   musical_instruments            200.0              38.0
#
#   Product_height_cm Product_width_cm
# 0              10.0             14.0
# 1              18.0             20.0
# 2               9.0             15.0
# 3              17.0             13.0
# 4               5.0             11.0

# %%
# products shape 확인
products.shape
# Out:
# (29471, 6)

# %%
# 컬럼명 변경
products = products.rename(columns={'Product_id':'제품 고유 ID'})
products = products.rename(columns={'Product_category_name':'카테고리 이름'})
products = products.rename(columns={'Product_weight_g':'제품 무게(g)'})
products = products.rename(columns={'Product_length_cm':'제품 길이(cm)'})
products = products.rename(columns={'Product_height_cm':'제품 높이(cm)'})
products = products.rename(columns={'Product_width_cm':'제품 너비(cm)'})
products.head()
# Out:
#         제품 고유 ID              카테고리 이름 제품 무게(g) 제품 길이(cm) 제품 높이(cm) 제품 너비(cm)
# 0  PRODUCT_00000            perfumery    225.0      16.0      10.0      14.0
# 1  PRODUCT_00001                 arts   1000.0      30.0      18.0      20.0
# 2  PRODUCT_00002       sports_leisure    154.0      18.0       9.0      15.0
# 3  PRODUCT_00003       home_utilities    625.0      20.0      17.0      13.0
# 4  PRODUCT_00004  musical_instruments    200.0      38.0       5.0      11.0

# %%
products['카테고리 이름'].unique()
# Out:
# array(['perfumery', 'arts', 'sports_leisure', 'home_utilities',
#        'musical_instruments', 'cool_stuff', 'furniture_decor',
#        'home_appliances', 'toys', 'bed_bath_table', 'baby',
#        'construction_tools_safety', 'computers_accessories',
#        'health_beauty', 'luggage_accessories', 'garden_tools',
#        'office_furniture', 'automotive', 'electronics', 'fashion_shoes',
#        'telephony', 'stationery', 'fashion_bags_accessories', 'pcs',
#        'home_construction', 'watches_gifts',
#        'construction_tools_construction', 'pet_shop', 'small_appliances',
#        'agro_industry_and_commerce', 'Unknown', 'living_room_furniture',
#        'air_conditioning', 'consoles_games', 'books_general_interest',
#        'fashion_underwear_beachwear', 'fashion_mens_clothing',
#        'kitchen_laundry_room_dining_garden_furniture',
#        'industry_commerce_and_business', 'landline_phones',
#        'technical_books', 'home_appliances_2', 'drinks', 'marketplace',
# ...

# %%
import numpy as np
categories = products['카테고리 이름'].unique()

# 카테고리 매핑
category_mapping = {
    'perfumery': 'health_beauty',
    'arts': 'arts_crafts',
    'sports_leisure': 'sports',
    'home_utilities': 'home',
    'musical_instruments': 'music',
    'cool_stuff': 'miscellaneous',
    'furniture_decor': 'home',
    'home_appliances': 'home',
    'toys': 'toys',
    'bed_bath_table': 'home',
    'baby': 'baby',
    'construction_tools_safety': 'construction',
    'computers_accessories': 'electronics',
    'health_beauty': 'health_beauty',
    'luggage_accessories': 'fashion',
    'garden_tools': 'home',
    'office_furniture': 'home',
    'automotive': 'automotive',
    'electronics': 'electronics',
    'fashion_shoes': 'fashion',
    'telephony': 'electronics',
    'stationery': 'office_supplies',
    'fashion_bags_accessories': 'fashion',
    'pcs': 'electronics',
    'home_construction': 'construction',
    'watches_gifts': 'fashion',
    'construction_tools_construction': 'construction',
    'pet_shop': 'pets',
    'small_appliances': 'home',
    'agro_industry_and_commerce': 'industry_commerce',
    'Unknown': 'miscellaneous',
    'living_room_furniture': 'home',
    'air_conditioning': 'home',
    'consoles_games': 'electronics',
    'books_general_interest': 'books',
    'fashion_underwear_beachwear': 'fashion',
    'fashion_mens_clothing': 'fashion',
    'kitchen_laundry_room_dining_garden_furniture': 'home',
    'industry_commerce_and_business': 'industry_commerce',
    'landline_phones': 'electronics',
    'technical_books': 'books',
    'home_appliances_2': 'home',
    'drinks': 'food_drink',
    'marketplace': 'miscellaneous',
    'the_kitchen': 'home',
    'construction_tools': 'construction',
    'signaling_and_security': 'construction',
    'fashion_womens_clothing': 'fashion',
    'home_comfort': 'home',
    'audio': 'electronics',
    'music': 'music',
    'food': 'food_drink',
    'party_supplies': 'miscellaneous',
    'food_drink': 'food_drink',
    'tablets_printing_image': 'electronics',
    'construction_tools_garden': 'construction',
    'portable_home_oven_and_coffee': 'home',
    'fashion_sport': 'fashion',
    'christmas_articles': 'miscellaneous',
    'fashion_childrens_clothes': 'fashion',
    'blu_ray_dvds': 'electronics',
    'construction_tools_lighting': 'construction',
    'bedroom_furniture': 'home',
    'cinema_photo': 'electronics',
    'imported_books': 'books',
    'diapers_hygiene': 'baby',
    'flowers': 'miscellaneous',
    'home_comfort_2': 'home',
    'insurance_and_services': 'services',
    'furniture_mattress_and_upholstery': 'home',
    'arts_and_crafts': 'arts_crafts',
    'musical_cds_dvds': 'music'
}

# 덜 세분화된 카테고리로 매핑
less_detailed_categories = np.array([category_mapping[cat] for cat in categories])

# 고유한 상위 카테고리 수 계산
unique_categories = np.unique(less_detailed_categories)
num_unique_categories = len(unique_categories)

print("고유한 상위 카테고리:", unique_categories)
print("고유한 상위 카테고리 수:", num_unique_categories)
# Out:
# 고유한 상위 카테고리: ['arts_crafts' 'automotive' 'baby' 'books' 'construction' 'electronics'
#  'fashion' 'food_drink' 'health_beauty' 'home' 'industry_commerce'
#  'miscellaneous' 'music' 'office_supplies' 'pets' 'services' 'sports'
#  'toys']
# 고유한 상위 카테고리 수: 18

# %%
products['상위 카테고리'] =  products['카테고리 이름'].map(category_mapping)
products.head()
# Out:
#         제품 고유 ID              카테고리 이름 제품 무게(g) 제품 길이(cm) 제품 높이(cm) 제품 너비(cm)  \
# 0  PRODUCT_00000            perfumery    225.0      16.0      10.0      14.0
# 1  PRODUCT_00001                 arts   1000.0      30.0      18.0      20.0
# 2  PRODUCT_00002       sports_leisure    154.0      18.0       9.0      15.0
# 3  PRODUCT_00003       home_utilities    625.0      20.0      17.0      13.0
# 4  PRODUCT_00004  musical_instruments    200.0      38.0       5.0      11.0
#
#          상위 카테고리
# 0  health_beauty
# 1    arts_crafts
# 2         sports
# 3           home
# 4          music

# %%
# products 정보 확인
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29471 entries, 0 to 29470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   제품 고유 ID   29471 non-null  object
#  1   카테고리 이름    29471 non-null  object
#  2   제품 무게(g)   29471 non-null  object
#  3   제품 길이(cm)  29471 non-null  object
#  4   제품 높이(cm)  29471 non-null  object
#  5   제품 너비(cm)  29471 non-null  object
#  6   상위 카테고리    29471 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
# products 결측치 확인
products.isnull().sum()
# Out:
# 제품 고유 ID     0
# 카테고리 이름      0
# 제품 무게(g)     0
# 제품 길이(cm)    0
# 제품 높이(cm)    0
# 제품 너비(cm)    0
# 상위 카테고리      0
# dtype: int64

# %%
# products 중복값 확인
print(products.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## reviews

# %%
# reviews 데이터 확인
reviews.head()
# Out:
#       Review_id     Order_id  Review_score Review_creation_date  \
# 0  REVIEW_00000  ORDER_01674             4  2019-01-18 00:00:00
# 1  REVIEW_00001  ORDER_80140             5  2019-03-10 00:00:00
# 2  REVIEW_00002  ORDER_69816             5  2019-02-17 00:00:00
# 3  REVIEW_00003  ORDER_24398             5  2018-04-21 00:00:00
# 4  REVIEW_00004  ORDER_70366             5  2019-03-01 00:00:00
#
#   Review_answer_timestamp
# 0     2019-01-18 21:46:59
# 1     2019-03-11 03:05:13
# 2     2019-02-18 14:36:24
# 3     2018-04-21 22:02:06
# 4     2019-03-02 10:26:53

# %%
# reviews shape 확인
reviews.shape
# Out:
# (87873, 5)

# %%
# 컬럼명 변경
reviews = reviews.rename(columns={'Review_id':'리뷰 고유 ID'})
reviews = reviews.rename(columns={'Order_id':'주문 고유 ID'})
reviews = reviews.rename(columns={'Review_score':'리뷰 점수'})
reviews = reviews.rename(columns={'Review_creation_date':'리뷰 생성 시간'})
reviews = reviews.rename(columns={'Review_answer_timestamp':'리뷰 답변 시간'})
reviews.head()
# Out:
#        리뷰 고유 ID     주문 고유 ID  리뷰 점수             리뷰 생성 시간             리뷰 답변 시간
# 0  REVIEW_00000  ORDER_01674      4  2019-01-18 00:00:00  2019-01-18 21:46:59
# 1  REVIEW_00001  ORDER_80140      5  2019-03-10 00:00:00  2019-03-11 03:05:13
# 2  REVIEW_00002  ORDER_69816      5  2019-02-17 00:00:00  2019-02-18 14:36:24
# 3  REVIEW_00003  ORDER_24398      5  2018-04-21 00:00:00  2018-04-21 22:02:06
# 4  REVIEW_00004  ORDER_70366      5  2019-03-01 00:00:00  2019-03-02 10:26:53

# %%
# reviews 정보 확인
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87873 entries, 0 to 87872
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   리뷰 고유 ID  87873 non-null  object
#  1   주문 고유 ID  87873 non-null  object
#  2   리뷰 점수     87873 non-null  int64
#  3   리뷰 생성 시간  87873 non-null  object
#  4   리뷰 답변 시간  87873 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
# reviews 결측치 확인
reviews.isnull().sum()
# Out:
# 리뷰 고유 ID    0
# 주문 고유 ID    0
# 리뷰 점수       0
# 리뷰 생성 시간    0
# 리뷰 답변 시간    0
# dtype: int64

# %%
# reviews 중복값 확인
print(reviews.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# ## sellers

# %%
# sellers 데이터 확인
sellers.head()
# Out:
#      Seller_id  Seller_zipcode_prefix        Seller_city Seller_state
# 0  SELLER_0000                  13023           campinas           SP
# 1  SELLER_0001                  13844         mogi guacu           SP
# 2  SELLER_0002                  12914  braganca paulista           SP
# 3  SELLER_0003                  20920     rio de janeiro           RJ
# 4  SELLER_0004                  55325             brejao           PE

# %%
# sellers shape 확인
sellers.shape
# Out:
# (2763, 4)

# %%
# 컬럼명 변경
sellers = sellers.rename(columns={'Seller_id':'판매자 고유 ID'})
sellers = sellers.rename(columns={'Seller_zipcode_prefix':'판매자 우편번호 앞자리'})
sellers = sellers.rename(columns={'Seller_city':'판매자 도시(city)'})
sellers = sellers.rename(columns={'Seller_state':'판매자 주(state)'})
sellers.head()
# Out:
#      판매자 고유 ID  판매자 우편번호 앞자리       판매자 도시(city) 판매자 주(state)
# 0  SELLER_0000         13023           campinas           SP
# 1  SELLER_0001         13844         mogi guacu           SP
# 2  SELLER_0002         12914  braganca paulista           SP
# 3  SELLER_0003         20920     rio de janeiro           RJ
# 4  SELLER_0004         55325             brejao           PE

# %%
# sellers 정보 확인
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2763 entries, 0 to 2762
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   판매자 고유 ID     2763 non-null   object
#  1   판매자 우편번호 앞자리  2763 non-null   int64
#  2   판매자 도시(city)  2763 non-null   object
#  3   판매자 주(state)  2763 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 86.5+ KB

# %%
# sellers 결측치 확인
sellers.isnull().sum()
# Out:
# 판매자 고유 ID       0
# 판매자 우편번호 앞자리    0
# 판매자 도시(city)    0
# 판매자 주(state)    0
# dtype: int64

# %%
# sellers 중복값 확인
print(sellers.duplicated(keep=False).sum())
# Out:
# 0

# %% [markdown]
# # 전처리

# %% [markdown]
# ## location 중복행 제거

# %%
# 중복행 제거
# 1000163 -> 738332
locations = locations.drop_duplicates()
locations.shape
# Out:
# (738332, 5)

# %% [markdown]
# ## 컬럼 타입 변경

# %%
products.columns
# Out:
# Index(['제품 고유 ID', '카테고리 이름', '제품 무게(g)', '제품 길이(cm)', '제품 높이(cm)',
#        '제품 너비(cm)', '상위 카테고리'],
#       dtype='object')

# %%
# "Unknown"을 NaN으로 대체
products['제품 무게(g)'] = products['제품 무게(g)'].replace('Unknown', pd.NA)
products['제품 길이(cm)'] = products['제품 길이(cm)'].replace('Unknown', pd.NA)
products['제품 높이(cm)'] = products['제품 높이(cm)'].replace('Unknown', pd.NA)
products['제품 너비(cm)'] = products['제품 너비(cm)'].replace('Unknown', pd.NA)

# Unknown 포함 행 삭제
products = products.dropna()

# 제품 무게,길이,높이,너비 컬럼타입 변경
products['제품 무게(g)']=pd.to_numeric(products['제품 무게(g)'])
products['제품 길이(cm)']=pd.to_numeric(products['제품 길이(cm)'])
products['제품 높이(cm)']=pd.to_numeric(products['제품 높이(cm)'])
products['제품 너비(cm)']=pd.to_numeric(products['제품 너비(cm)'])

# products 변경정보 확인
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29469 entries, 0 to 29470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   제품 고유 ID   29469 non-null  object
#  1   카테고리 이름    29469 non-null  object
#  2   제품 무게(g)   29469 non-null  float64
#  3   제품 길이(cm)  29469 non-null  float64
#  4   제품 높이(cm)  29469 non-null  float64
#  5   제품 너비(cm)  29469 non-null  float64
#  6   상위 카테고리    29469 non-null  object
# dtypes: float64(4), object(3)
# memory usage: 1.8+ MB
# <ipython-input-58-77f5769ef241>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products['제품 무게(g)']=pd.to_numeric(products['제품 무게(g)'])
# <ipython-input-58-77f5769ef241>:12: SettingWithCopyWarning:
# ...

# %%
# 주문 시간 관련 컬럼 타입변경
orders['구매 시간']=pd.to_datetime(orders["구매 시간"])
orders['물류 처리 시간']=pd.to_datetime(orders["물류 처리 시간"])
orders['실제 배송 날짜']=pd.to_datetime(orders["실제 배송 날짜"])
orders['기대 배송 날짜']=pd.to_datetime(orders["기대 배송 날짜"])

# orders 정보 확인
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87955 entries, 0 to 87954
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   주문 고유 ID  87955 non-null  object
#  1   고객 ID     87955 non-null  object
#  2   주문 상태     87955 non-null  object
#  3   구매 시간     87955 non-null  datetime64[ns]
#  4   물류 처리 시간  87955 non-null  datetime64[ns]
#  5   실제 배송 날짜  87955 non-null  datetime64[ns]
#  6   기대 배송 날짜  87955 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(3)
# memory usage: 4.7+ MB

# %%
from datetime import datetime

# 리뷰 시간 관련 컬럼 타입변경
reviews['리뷰 생성 시간']=pd.to_datetime(reviews["리뷰 생성 시간"])
reviews['리뷰 답변 시간']=pd.to_datetime(reviews["리뷰 답변 시간"])

# 년월일 데이터만 사용
reviews['리뷰 생성 시간'] = reviews['리뷰 생성 시간'].apply(lambda x: x.strftime('%Y-%m-%d'))
reviews['리뷰 답변 시간'] = reviews['리뷰 답변 시간'].apply(lambda x: x.strftime('%Y-%m-%d'))

# reviews 정보 확인
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87873 entries, 0 to 87872
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   리뷰 고유 ID  87873 non-null  object
#  1   주문 고유 ID  87873 non-null  object
#  2   리뷰 점수     87873 non-null  int64
#  3   리뷰 생성 시간  87873 non-null  object
#  4   리뷰 답변 시간  87873 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ MB

# %%
reviews.head()
# Out:
#        리뷰 고유 ID     주문 고유 ID  리뷰 점수    리뷰 생성 시간    리뷰 답변 시간
# 0  REVIEW_00000  ORDER_01674      4  2019-01-18  2019-01-18
# 1  REVIEW_00001  ORDER_80140      5  2019-03-10  2019-03-11
# 2  REVIEW_00002  ORDER_69816      5  2019-02-17  2019-02-18
# 3  REVIEW_00003  ORDER_24398      5  2018-04-21  2018-04-21
# 4  REVIEW_00004  ORDER_70366      5  2019-03-01  2019-03-02

# %% [markdown]
# ## 포르투갈 표기 수정

# %%
def replace_portuguese_characters(text):
    replacements = {
        'á': 'a', 'à': 'a', 'â': 'a', 'ã': 'a', 'ä': 'a',
        'Á': 'A', 'À': 'A', 'Â': 'A', 'Ã': 'A', 'Ä': 'A',
        'é': 'e', 'è': 'e', 'ê': 'e', 'ë': 'e',
        'É': 'E', 'È': 'E', 'Ê': 'E', 'Ë': 'E',
        'í': 'i', 'ì': 'i', 'î': 'i', 'ï': 'i',
        'Í': 'I', 'Ì': 'I', 'Î': 'I', 'Ï': 'I',
        'ó': 'o', 'ò': 'o', 'ô': 'o', 'õ': 'o', 'ö': 'o',
        'Ó': 'O', 'Ò': 'O', 'Ô': 'O', 'Õ': 'O', 'Ö': 'O',
        'ú': 'u', 'ù': 'u', 'û': 'u', 'ü': 'u',
        'Ú': 'U', 'Ù': 'U', 'Û': 'U', 'Ü': 'U',
        'ç': 'c', 'Ç': 'C',
        'ñ': 'n', 'Ñ': 'N'
    }

    for original, replacement in replacements.items():
        text = text.replace(original, replacement)

    return text

# %%
# 포르투갈어 표기를 영어로 수정
locations['도시'] = locations['도시'].apply(replace_portuguese_characters)
sellers['판매자 도시(city)'] = sellers['판매자 도시(city)'].apply(replace_portuguese_characters)
customers['고객 도시'] = customers['도시'].apply(replace_portuguese_characters)

# %%
# 주 이름을 한글로 바꾸는 함수
def get_kor_state(state) :
    if state == 'AC' :
        state_kor_name = '아크리주'
    elif state == 'AL' :
        state_kor_name = '알라고아스주'
    elif state == 'AP' :
        state_kor_name = '아마파주'
    elif state == 'AM' :
        state_kor_name = '아마조나스주'
    elif state == 'BA' :
        state_kor_name = '바이아주'
    elif state == 'CE' :
        state_kor_name = '세아라주'
    elif state == 'DF' :
        state_kor_name = '연방구'
    elif state == 'ES' :
        state_kor_name = '이스피리투산투주'
    elif state == 'GO' :
        state_kor_name = '고이아스주'
    elif state == 'MA' :
        state_kor_name = '마라냥주'
    elif state == 'MT' :
        state_kor_name = '마투그로수주'
    elif state == 'MG' :
        state_kor_name = '미나스제라이스주'
    elif state == 'PA' :
        state_kor_name = '파라주'
    elif state == 'PB' :
        state_kor_name = '파라이바주'
    elif state == 'PR' :
        state_kor_name = '파라나주'
    elif state == 'PE' :
        state_kor_name = '페르남부쿠주'
    elif state == 'PI' :
        state_kor_name = '피아우이주'
    elif state == 'RJ' :
        state_kor_name = '리우데자네이루주'
    elif state == 'RN' :
        state_kor_name = '히우그란지두노르치주'
    elif state == 'RS' :
        state_kor_name = '히우그란지두술주'
    elif state == 'RO' :
        state_kor_name = '혼도니아주'
    elif state == 'RR' :
        state_kor_name = '호라이마주'
    elif state == 'SC' :
        state_kor_name = '산타카타리나주'
    elif state == 'SP' :
        state_kor_name = '상파울루주'
    elif state == 'SE' :
        state_kor_name = '세르지피주'
    elif state == 'MS' :
        state_kor_name = '마투그로수두술'
    else :
        state_kor_name = '토칸칭스주'
    return state_kor_name

# customers 주의 한글 이름 컬럼 추가
for index, row in customers.iterrows():
    state = row['주']
    kor_name = get_kor_state(state)
    customers.at[index,'주 한국명'] = kor_name

# sellers 주의 한글 이름 컬럼 추가
for index, row in sellers.iterrows():
   state = row['판매자 주(state)']
   kor_name = get_kor_state(state)
   sellers.at[index,'주 한국명'] = kor_name

# locations 주의 한글 이름 컬럼 추가
for index, row in locations.iterrows():
    state = row['주']
    kor_name = get_kor_state(state)
    locations.at[index,'주 한국명'] = kor_name

# %% [markdown]
# ## 지역 분할

# %%
# state를 입력받으면 지역을 return하는 함수
def get_region(state) :
    if (state == 'SP' or state == 'MG' or state == 'ES' or state == 'RJ') :
        region = '남동부'
    elif (state == 'PR' or state == 'SC' or state == 'RS') :
        region = '남부'
    elif (state == 'BA' or state == 'PE' or state == 'CE' or state == 'RN' or state == 'PI' or state == 'MA' or state == 'SE' or state == 'AL' or state == 'PB') :
        region = '북동부'
    elif (state == 'GO' or state == 'MT' or state == 'MS' or state == 'DF') :
        region = '중서부'
    else :
        region = '북부'
    return region

# 판매자 거주 지역 컬럼 추가
for index, row in sellers.iterrows():
   state = row['판매자 주(state)']
   region = get_region(state)
   sellers.at[index,'지역'] = region

# 위치 테이블 지역 컬럼 추가
for index, row in locations.iterrows():
    state = row['주']
    region = get_region(state)
    locations.at[index,'지역'] = region

# 고객 테이블 지역 컬럼 추가
for index, row in customers.iterrows():
    state = row['주']
    region = get_region(state)
    customers.at[index,'지역'] = region

# %%
sellers.head()
# Out:
#      판매자 고유 ID  판매자 우편번호 앞자리       판매자 도시(city) 판매자 주(state)     주 한국명   지역
# 0  SELLER_0000         13023           campinas           SP     상파울루주  남동부
# 1  SELLER_0001         13844         mogi guacu           SP     상파울루주  남동부
# 2  SELLER_0002         12914  braganca paulista           SP     상파울루주  남동부
# 3  SELLER_0003         20920     rio de janeiro           RJ  리우데자네이루주  남동부
# 4  SELLER_0004         55325             brejao           PE    페르남부쿠주  북동부

# %%
customers.head()
# Out:
#             고객 ID               고객 고유 ID  우편번호 앞부분                     도시   주  \
# 0  CUSTOMER_00000  CUSTOMER_Unique_00000     14409                 franca  SP
# 1  CUSTOMER_00001  CUSTOMER_Unique_00001      9790  sao bernardo do campo  SP
# 2  CUSTOMER_00002  CUSTOMER_Unique_00002      1151              sao paulo  SP
# 3  CUSTOMER_00003  CUSTOMER_Unique_00003      8775        mogi das cruzes  SP
# 4  CUSTOMER_00004  CUSTOMER_Unique_00004     89254         jaragua do sul  SC
#
#                    고객 도시    주 한국명   지역
# 0                 franca    상파울루주  남동부
# 1  sao bernardo do campo    상파울루주  남동부
# 2              sao paulo    상파울루주  남동부
# 3        mogi das cruzes    상파울루주  남동부
# 4         jaragua do sul  산타카타리나주   남부

# %%
locations.head()
# Out:
#    우편번호 앞부분         위도         경도         도시   주  주 한국명   지역
# 0      1037 -23.545621 -46.639292  sao paulo  SP  상파울루주  남동부
# 1      1046 -23.546081 -46.644820  sao paulo  SP  상파울루주  남동부
# 2      1046 -23.546129 -46.642951  sao paulo  SP  상파울루주  남동부
# 3      1041 -23.544392 -46.639499  sao paulo  SP  상파울루주  남동부
# 4      1035 -23.541578 -46.641607  sao paulo  SP  상파울루주  남동부

# %% [markdown]
# ## locations 데이터 제거 및 대체

# %%
locations.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 738332 entries, 0 to 1000161
# Data columns (total 7 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   우편번호 앞부분  738332 non-null  int64
#  1   위도        738332 non-null  float64
#  2   경도        738332 non-null  float64
#  3   도시        738332 non-null  object
#  4   주         738332 non-null  object
#  5   주 한국명     738332 non-null  object
#  6   지역        738332 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 61.2+ MB

# %%
# locations에서 브라질을 벗어나는 데이터 제거
lat_range = (-33, 5)
lng_range = (-74, -34)
condition1 = (locations['위도'].between(lat_range[0], lat_range[1], 'both'))
condition2 = (locations['경도'].between(lng_range[0], lng_range[1], 'both'))
locations = locations.loc[condition1 & condition2, :]

# %%
# locations 데이터의 중복값을 중앙값으로 대체
locations = locations.groupby(by=['우편번호 앞부분', '도시', '주','주 한국명','지역'], as_index=False).median()

# %%
locations.shape
# Out:
# (19609, 7)

# %%
# customers 중복값 확인
print(locations.duplicated(keep=False).sum())
# Out:
# 0

# %%
locations.head()
# Out:
#    우편번호 앞부분         도시   주  주 한국명   지역         위도         경도
# 0      1001  sao paulo  SP  상파울루주  남동부 -23.549951 -46.634027
# 1      1002  sao paulo  SP  상파울루주  남동부 -23.548228 -46.635247
# 2      1003  sao paulo  SP  상파울루주  남동부 -23.548977 -46.635313
# 3      1004  sao paulo  SP  상파울루주  남동부 -23.549550 -46.634771
# 4      1005  sao paulo  SP  상파울루주  남동부 -23.549763 -46.636100

# %% [markdown]
# # 테이블 미 조인 전처리 데이터

# %%
customers.to_csv('customers_final.csv',index= False)
locations.to_csv('locations_final.csv',index= False)
order_items.to_csv('order_items_final.csv',index= False)
orders.to_csv('orders_final.csv',index= False)
payments.to_csv('payments_final.csv',index= False)
products.to_csv('products_final.csv',index= False)
reviews.to_csv('reviews_final.csv',index= False)
sellers.to_csv('sellers_final.csv',index= False)

# %% [markdown]
# # 테이블 조인

# %%
# customer + location
customer_loc = pd.merge(customers, locations, on=['우편번호 앞부분','도시', '주'], how='left')

# 위도 경도 명 변경
customer_loc = customer_loc.rename(columns={'위도': '고객 위도', '경도': '고객 경도'})

customer_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87955 entries, 0 to 87954
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   고객 ID     87955 non-null  object
#  1   고객 고유 ID  87955 non-null  object
#  2   우편번호 앞부분  87955 non-null  int64
#  3   도시        87955 non-null  object
#  4   주         87955 non-null  object
#  5   고객 도시     87955 non-null  object
#  6   주 한국명_x   87955 non-null  object
#  7   지역_x      87955 non-null  object
#  8   주 한국명_y   87684 non-null  object
#  9   지역_y      87684 non-null  object
#  10  고객 위도     87684 non-null  float64
#  11  고객 경도     87684 non-null  float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 8.1+ MB

# %%
# customers 중복값 확인
print(customer_loc.duplicated(keep=False).sum())
# Out:
# 0

# %%
customer_loc.head()
# Out:
#             고객 ID               고객 고유 ID  우편번호 앞부분                     도시   주  \
# 0  CUSTOMER_00000  CUSTOMER_Unique_00000     14409                 franca  SP
# 1  CUSTOMER_00001  CUSTOMER_Unique_00001      9790  sao bernardo do campo  SP
# 2  CUSTOMER_00002  CUSTOMER_Unique_00002      1151              sao paulo  SP
# 3  CUSTOMER_00003  CUSTOMER_Unique_00003      8775        mogi das cruzes  SP
# 4  CUSTOMER_00004  CUSTOMER_Unique_00004     89254         jaragua do sul  SC
#
#                    고객 도시  주 한국명_x 지역_x  주 한국명_y 지역_y      고객 위도      고객 경도
# 0                 franca    상파울루주  남동부    상파울루주  남동부 -20.502307 -47.396740
# 1  sao bernardo do campo    상파울루주  남동부    상파울루주  남동부 -23.730435 -46.541474
# 2              sao paulo    상파울루주  남동부    상파울루주  남동부 -23.531294 -46.656980
# 3        mogi das cruzes    상파울루주  남동부    상파울루주  남동부 -23.499025 -46.183436
# 4         jaragua do sul  산타카타리나주   남부  산타카타리나주   남부 -26.471054 -49.114024

# %%
# order + customer
tmp = pd.merge(orders, customer_loc, on='고객 ID', how='outer')
tmp.shape
# Out:
# (87955, 18)

# %%
# tmp + order_items
tmp2 = pd.merge(tmp, order_items, on = '주문 고유 ID',how='left')
tmp2.shape
# Out:
# (100558, 23)

# %%
# tmp2 + payment
tmp3 = pd.merge(tmp2, payments, on = '주문 고유 ID',how='left')
tmp3.shape
# Out:
# (105087, 27)

# %%
# tmp3 + reviews
tmp4 = pd.merge(tmp3, reviews, on = '주문 고유 ID',how='left')
tmp4.shape
# Out:
# (105767, 31)

# %%
# tmp4 + products
tmp5 = pd.merge(tmp4, products, on = '제품 고유 ID',how='left')
tmp5.shape
# Out:
# (105767, 37)

# %%
# tmp5 + seller
tmp6 = pd.merge(tmp5, sellers, on = '판매자 고유 ID',how='left')
tmp6.shape
# Out:
# (105767, 42)

# %% [markdown]
# ## 총구매금액 컬럼 추가

# %%
tmp6['총구매금액'] = tmp6['거래 금액'] * tmp6['판매 가격']

tmp6.shape
# Out:
# (105767, 43)

# %%
tmp6.columns
# Out:
# Index(['주문 고유 ID', '고객 ID', '주문 상태', '구매 시간', '물류 처리 시간', '실제 배송 날짜',
#        '기대 배송 날짜', '고객 고유 ID', '우편번호 앞부분', '도시', '주', '고객 도시', '주 한국명_x',
#        '지역_x', '주 한국명_y', '지역_y', '고객 위도', '고객 경도', '주문 품목 수', '제품 고유 ID',
#        '판매자 고유 ID', '판매 가격', '품목 화물 가격', '결제 시퀀스', '지불 방법 ', '할부 횟수', '거래 금액',
#        '리뷰 고유 ID', '리뷰 점수', '리뷰 생성 시간', '리뷰 답변 시간', '카테고리 이름', '제품 무게(g)',
#        '제품 길이(cm)', '제품 높이(cm)', '제품 너비(cm)', '상위 카테고리', '판매자 우편번호 앞자리',
#        '판매자 도시(city)', '판매자 주(state)', '주 한국명', '지역', '총구매금액'],
#       dtype='object')

# %%
tmp6.to_csv('최종합본_final.csv',index= False)
tmp6.to_excel('최종합본_final.xlsx',index= False)
